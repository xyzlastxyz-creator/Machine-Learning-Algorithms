# %% [markdown]
# ## Single Variable Linear Regression
#
# Simple linear regression can be used to model a linear relationship between one response variable and one explanatory variable
#
# Predicting Pizza prices
#
# Let's model the relationship between the size of a pizza and its price. First,
# we will write a program with scikit-learn that can predict the price of a pizza given  its size. Then, we will discuss how simple linear regression works and how it can  be generalized to work with other types of problems. Let's assume that you have  recorded the diameters and prices of pizzas that you have previously eaten in your pizza journal
#
# Training instance Diameter (in inches) Price (in dollars)
#
# | Record | Diameter(Inch) | Price$|
# |--------|----------------|-------|
# | 1      |  6             |  7    |
# | 2      |  8             |  9    |
# | 3      |  10            |  13   |
# | 4      |  14            |  17.5 |
# | 5      |  18            |  18   |

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# List of List input and output format is important 
# Ordinary Least Square takes Multiple Input and Predicts Multiple Outputs

# Read the Excel file
# df = pd.read_excel("pizza_data.xlsx") #excel file saved in same folder (downloads)

PSize = [[6], [8], [10], [14], [18]] #input has to lists of lists
PPrice = [7, 9, 13, 17.5, 18] #outputs is a single list

plt.figure() #giving instruction to get 1 figure for visualisation
plt.title('Pizza price plotted against diameter') #title for figure
plt.xlabel('Diameter in inches') # title of x
plt.ylabel('Price in dollars') # title of y
plt.plot(PSize, PPrice, 'go') # declaring figure as plot
plt.axis([0, 25, 0, 25]) #xlims & ylims together xlims[0,25]
plt.grid(True) #show the grids on plot
plt.show() #display the plot

# %%
from sklearn.model_selection import train_test_split
PSize_train, PSize_test, PPrice_train, PPrice_test = \
train_test_split(PSize, PPrice, test_size=0.2) # 20% = test

plt.figure()
plt.title('Pizza price plotted against diameter')
plt.xlabel('Diameter in inches')
plt.ylabel('Price in dollars')
plt.plot(PSize_train, PPrice_train, 'go')
plt.axis([0, 25, 0, 25])
plt.grid(True)
plt.show()

plt.figure()
plt.title('Pizza price plotted against diameter for testing')
plt.xlabel('Diameter in inches')
plt.ylabel('Price in dollars')
plt.plot(PSize_test, PPrice_test, 'go')
plt.axis([0, 25, 0, 25])
plt.grid(True)
plt.show()

# %%
#applying linear regression on training data
from sklearn.linear_model import LinearRegression 
#scikit learn lib is used for major machine learning purpose


# Create and fit the model
model = LinearRegression() #taking linear regression in variable "model"
#fitting all training data(80% of data) in model which has liner regression concepts
model.fit(PSize_train, PPrice_train) 


# displaying testing data
print(PPrice_test)                          ## Test output - Expected Output
model.predict(PSize_test)                   ## Observe Output its a single list
# Out:
# [7]
# array([8.61864407])

# %%
# Plot Initial Data 
plt.figure()
plt.title('Pizza Price Prediction against diameter')
plt.xlabel('Diameter in inches')
plt.ylabel('Price in dollars')
plt.plot(PSize_train, PPrice_train, 'go')
plt.plot(PSize_test, PPrice_test, 'bo')

plt.axis([0, 25, 0, 25])
plt.grid()
plt.show()

# Plot Regression Solution line
regression_line_y = model.predict([[0], [25]])
print(regression_line_y)
plt.plot([0, 25], regression_line_y, 
         color='r', linestyle='-', linewidth=2)
plt.show()
# Out:
# [ 3.30508475 25.44491525]

# %%
pr = int(input("Enter Diameter(Inch) : "))
print('pizza should cost: $%.2f' % model.predict([[pr]]))     # Prediction of inexperienced data
# Out:
# Enter Diameter(Inch) :  20
# pizza should cost: $21.02
# C:\Users\Krinal\AppData\Local\Temp\ipykernel_26620\3804087943.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('pizza should cost: $%.2f' % model.predict([[pr]]))     # Prediction of inexperienced data

# %%
model.score(PSize, PPrice)
# Out:
# 0.8967565549845546

# %%
print("Slope(m) : %.2f, Intercept (c): %.2f"%
      (model.coef_, model.intercept_))
# Out:
# Slope(m) : 0.89, Intercept (c): 3.31
# C:\Users\Krinal\AppData\Local\Temp\ipykernel_26620\4028551605.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Slope(m) : %.2f, Intercept (c): %.2f"%
